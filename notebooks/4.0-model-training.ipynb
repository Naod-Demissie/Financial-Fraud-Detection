# %% [markdown]
# # <center><font color = '#DF9166' size = 20 center> **Modeling**</font></center>

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Table of content**<font/><a class = 'anchor' id = 'introduction'/>

# %% [markdown]
# 1. [**Import Libraries**](#import)
# 2. [**Modeling**](#modeling)

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Import Libraries**<font/><a class = 'anchor' id = 'import'/>

# %%
import os
import sys
import warnings

warnings.filterwarnings("ignore")

# %%
sys.path.append(os.path.abspath(os.path.pardir))
from scripts.train_models import ClassicalModelTrainer, DeepModelTrainer

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Modeling**<font/><a class = 'anchor' id = 'modeling'/>

# %%
# Initialize ClassicalModelTrainer instance
classic_trainer = ClassicalModelTrainer()
# Out:
# Initialized ModelTrainer with MLflow tracking.

# %%
# Initialize DeepModelTrainer instance
deep_trainer = DeepModelTrainer()
# Out:
# Initialized DeepModelTrainer with MLflow tracking.

# %% [markdown]
# ### `creditcard_data` Modeling

# %% [markdown]
# #### Logistic Regression

# %%
classic_trainer.train_model("Logistic Regression", "creditcard_data")
# Out:
# Loading creditcard_data dataset...
# Shapes of loaded data for creditcard_data:
# X_train: (198608, 31), y_train: (198608,)
# X_val: (42559, 31), y_val: (42559,)
# X_test: (42559, 31), y_test: (42559,)
# Training Logistic Regression on creditcard_data dataset...
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Model saved as /content/checkpoints/best_Logistic_Regression_creditcard_data.joblib
# ...

# %%
classic_trainer.evaluate_model("Logistic Regression", "creditcard_data")
# Out:
# Loaded model from /content/checkpoints/best_Logistic_Regression_creditcard_data.joblib
# Evaluating on Validation set...
# Accuracy on Validation set: 0.9984
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     42488
#            1       1.00      0.04      0.08        71
#
#     accuracy                           1.00     42559
#    macro avg       1.00      0.52      0.54     42559
# weighted avg       1.00      1.00      1.00     42559
#
# Evaluating on Test set...
# Accuracy on Test set: 0.9984
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     42488
#            1       0.67      0.03      0.05        71
#
#     accuracy                           1.00     42559
#    macro avg       0.83      0.51      0.53     42559
# weighted avg       1.00      1.00      1.00     42559

# %% [markdown]
# #### Decision Tree

# %%
classic_trainer.train_model("Decision Tree", "creditcard_data")
# Out:
# Loading creditcard_data dataset...
# Shapes of loaded data for creditcard_data:
# X_train: (198608, 31), y_train: (198608,)
# X_val: (42559, 31), y_val: (42559,)
# X_test: (42559, 31), y_test: (42559,)
# Training Decision Tree on creditcard_data dataset...
# Model saved as /content/checkpoints/best_Decision_Tree_creditcard_data.joblib
# 2025/02/15 12:29:39 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
classic_trainer.evaluate_model("Decision Tree", "creditcard_data")
# Out:
# Loaded model from /content/checkpoints/best_Decision_Tree_creditcard_data.joblib
# Evaluating on Validation set...
# Accuracy on Validation set: 0.9981
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     42488
#            1       0.44      0.55      0.49        71
#
#     accuracy                           1.00     42559
#    macro avg       0.72      0.77      0.74     42559
# weighted avg       1.00      1.00      1.00     42559
#
# Evaluating on Test set...
# Accuracy on Test set: 0.9984
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     42488
#            1       0.51      0.54      0.52        71
#
#     accuracy                           1.00     42559
#    macro avg       0.75      0.77      0.76     42559
# weighted avg       1.00      1.00      1.00     42559

# %% [markdown]
# #### Random Forest

# %%
classic_trainer.train_model("Random Forest", "creditcard_data")
# Out:
# Loading creditcard_data dataset...
# Shapes of loaded data for creditcard_data:
# X_train: (198608, 31), y_train: (198608,)
# X_val: (42559, 31), y_val: (42559,)
# X_test: (42559, 31), y_test: (42559,)
# Training Random Forest on creditcard_data dataset...
# Model saved as /content/checkpoints/best_Random_Forest_creditcard_data.joblib
# 2025/02/15 12:33:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
classic_trainer.evaluate_model("Random Forest", "creditcard_data")
# Out:
# Loaded model from /content/checkpoints/best_Random_Forest_creditcard_data.joblib
# Evaluating on Validation set...
# Accuracy on Validation set: 0.9991
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     42488
#            1       0.97      0.49      0.65        71
#
#     accuracy                           1.00     42559
#    macro avg       0.99      0.75      0.83     42559
# weighted avg       1.00      1.00      1.00     42559
#
# Evaluating on Test set...
# Accuracy on Test set: 0.9993
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     42488
#            1       0.96      0.62      0.75        71
#
#     accuracy                           1.00     42559
#    macro avg       0.98      0.81      0.88     42559
# weighted avg       1.00      1.00      1.00     42559

# %% [markdown]
# #### Gradient Boosting

# %%
classic_trainer.train_model("Gradient Boosting", "creditcard_data")
# Out:
# Loading creditcard_data dataset...
# Shapes of loaded data for creditcard_data:
# X_train: (198608, 31), y_train: (198608,)
# X_val: (42559, 31), y_val: (42559,)
# X_test: (42559, 31), y_test: (42559,)
# Training Gradient Boosting on creditcard_data dataset...
# Model saved as /content/checkpoints/best_Gradient_Boosting_creditcard_data.joblib
# 2025/02/15 12:42:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
classic_trainer.evaluate_model("Gradient Boosting", "creditcard_data")
# Out:
# Loaded model from /content/checkpoints/best_Gradient_Boosting_creditcard_data.joblib
# Evaluating on Validation set...
# Accuracy on Validation set: 0.9987
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     42488
#            1       0.72      0.37      0.49        71
#
#     accuracy                           1.00     42559
#    macro avg       0.86      0.68      0.74     42559
# weighted avg       1.00      1.00      1.00     42559
#
# Evaluating on Test set...
# Accuracy on Test set: 0.9987
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     42488
#            1       0.68      0.42      0.52        71
#
#     accuracy                           1.00     42559
#    macro avg       0.84      0.71      0.76     42559
# weighted avg       1.00      1.00      1.00     42559

# %% [markdown]
# #### CNN

# %%
cnn_model = deep_trainer.initialize_model("CNN", "creditcard_data")
trained_cnn_model = deep_trainer.train_model(cnn_model, "CNN", "creditcard_data")
# Out:
# Loading creditcard_data dataset...
# Shapes of loaded data for creditcard_data:
# X_train: (198608, 31), y_train: (198608,)
# X_val: (42559, 31), y_val: (42559,)
# X_test: (42559, 31), y_test: (42559,)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/6
# 6203/6207 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9955 - loss: 14.5605
# Epoch 1: val_accuracy improved from -inf to 0.99833, saving model to /content/checkpoints/best_CNN_creditcard_data.h5
# ...

# %%
deep_trainer.evaluate_model(trained_cnn_model, "creditcard_data")
# Out:
# 1330/1330 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Classification Report for creditcard_data:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     42488
#            1       0.00      0.00      0.00        71
#
#     accuracy                           1.00     42559
#    macro avg       0.50      0.50      0.50     42559
# weighted avg       1.00      1.00      1.00     42559
#
# Accuracy Score for creditcard_data: 0.9983317277191663
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# #### RNN

# %%
rnn_model = deep_trainer.initialize_model("RNN", "creditcard_data")
trained_rnn_model = deep_trainer.train_model(rnn_model, "RNN", "creditcard_data")
# Out:
# Loading creditcard_data dataset...
# Shapes of loaded data for creditcard_data:
# X_train: (198608, 31), y_train: (198608,)
# X_val: (42559, 31), y_val: (42559,)
# X_test: (42559, 31), y_test: (42559,)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/6
# 6203/6207 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9921 - loss: 0.0500
# Epoch 1: val_accuracy improved from -inf to 0.99833, saving model to /content/checkpoints/best_RNN_creditcard_data.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ...

# %%
deep_trainer.evaluate_model(trained_rnn_model, "creditcard_data")
# Out:
# 1330/1330 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Classification Report for creditcard_data:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     42488
#            1       0.00      0.00      0.00        71
#
#     accuracy                           1.00     42559
#    macro avg       0.50      0.50      0.50     42559
# weighted avg       1.00      1.00      1.00     42559
#
# Accuracy Score for creditcard_data: 0.9983317277191663
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# #### LSTM

# %%
lstm_model = deep_trainer.initialize_model("LSTM", "creditcard_data")
trained_lstm_model = deep_trainer.train_model(lstm_model, "LSTM", "creditcard_data")
# Out:
# Loading creditcard_data dataset...
# Shapes of loaded data for creditcard_data:
# X_train: (198608, 31), y_train: (198608,)
# X_val: (42559, 31), y_val: (42559,)
# X_test: (42559, 31), y_test: (42559,)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/6
# 6204/6207 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9960 - loss: 60.2696
# Epoch 1: val_accuracy improved from -inf to 0.99833, saving model to /content/checkpoints/best_LSTM_creditcard_data.h5
# ...

# %%
deep_trainer.evaluate_model(trained_lstm_model, "creditcard_data")
# Out:
# 1330/1330 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step
# Classification Report for creditcard_data:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     42488
#            1       0.00      0.00      0.00        71
#
#     accuracy                           1.00     42559
#    macro avg       0.50      0.50      0.50     42559
# weighted avg       1.00      1.00      1.00     42559
#
# Accuracy Score for creditcard_data: 0.9983317277191663
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# ### `fraud_data` Modeling

# %% [markdown]
# #### Logistic Regression

# %%
classic_trainer.train_model("Logistic Regression", "fraud_data")
# Out:
# Loading fraud_data dataset...
# Shapes of loaded data for fraud_data:
# X_train: (90402, 12), y_train: (90402,)
# X_val: (19372, 12), y_val: (19372,)
# X_test: (19372, 12), y_test: (19372,)
# Training Logistic Regression on fraud_data dataset...
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Model saved as /content/checkpoints/best_Logistic_Regression_fraud_data.joblib
# ...

# %%
classic_trainer.evaluate_model("Logistic Regression", "fraud_data")
# Out:
# Loaded model from /content/checkpoints/best_Logistic_Regression_fraud_data.joblib
# Evaluating on Validation set...
# Accuracy on Validation set: 0.9050
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# #### Decision Tree

# %%
classic_trainer.train_model("Decision Tree", "fraud_data")
# Out:
# Loading fraud_data dataset...
# Shapes of loaded data for fraud_data:
# X_train: (90402, 12), y_train: (90402,)
# X_val: (19372, 12), y_val: (19372,)
# X_test: (19372, 12), y_test: (19372,)
# Training Decision Tree on fraud_data dataset...
# Model saved as /content/checkpoints/best_Decision_Tree_fraud_data.joblib
# 2025/02/15 12:43:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
classic_trainer.evaluate_model("Decision Tree", "fraud_data")
# Out:
# Loaded model from /content/checkpoints/best_Decision_Tree_fraud_data.joblib
# Evaluating on Validation set...
# Accuracy on Validation set: 0.9095
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95     17532
#            1       0.52      0.61      0.56      1840
#
#     accuracy                           0.91     19372
#    macro avg       0.74      0.77      0.75     19372
# weighted avg       0.92      0.91      0.91     19372
#
# Evaluating on Test set...
# Accuracy on Test set: 0.9088
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95     17532
#            1       0.52      0.60      0.56      1840
#
#     accuracy                           0.91     19372
#    macro avg       0.74      0.77      0.75     19372
# weighted avg       0.92      0.91      0.91     19372

# %% [markdown]
# #### Random Forest

# %%
classic_trainer.train_model("Random Forest", "fraud_data")
# Out:
# Loading fraud_data dataset...
# Shapes of loaded data for fraud_data:
# X_train: (90402, 12), y_train: (90402,)
# X_val: (19372, 12), y_val: (19372,)
# X_test: (19372, 12), y_test: (19372,)
# Training Random Forest on fraud_data dataset...
# Model saved as /content/checkpoints/best_Random_Forest_fraud_data.joblib
# 2025/02/15 12:43:33 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
classic_trainer.evaluate_model("Random Forest", "fraud_data")
# Out:
# Loaded model from /content/checkpoints/best_Random_Forest_fraud_data.joblib
# Evaluating on Validation set...
# Accuracy on Validation set: 0.9582
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     17532
#            1       1.00      0.56      0.72      1840
#
#     accuracy                           0.96     19372
#    macro avg       0.98      0.78      0.85     19372
# weighted avg       0.96      0.96      0.95     19372
#
# Evaluating on Test set...
# Accuracy on Test set: 0.9585
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     17532
#            1       1.00      0.56      0.72      1840
#
#     accuracy                           0.96     19372
#    macro avg       0.98      0.78      0.85     19372
# weighted avg       0.96      0.96      0.95     19372

# %% [markdown]
# #### Gradient Boosting

# %%
classic_trainer.train_model("Gradient Boosting", "fraud_data")
# Out:
# Loading fraud_data dataset...
# Shapes of loaded data for fraud_data:
# X_train: (90402, 12), y_train: (90402,)
# X_val: (19372, 12), y_val: (19372,)
# X_test: (19372, 12), y_test: (19372,)
# Training Gradient Boosting on fraud_data dataset...
# Model saved as /content/checkpoints/best_Gradient_Boosting_fraud_data.joblib
# 2025/02/15 12:44:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
classic_trainer.evaluate_model("Gradient Boosting", "fraud_data")
# Out:
# Loaded model from /content/checkpoints/best_Gradient_Boosting_fraud_data.joblib
# Evaluating on Validation set...
# Accuracy on Validation set: 0.9581
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     17532
#            1       1.00      0.56      0.72      1840
#
#     accuracy                           0.96     19372
#    macro avg       0.98      0.78      0.85     19372
# weighted avg       0.96      0.96      0.95     19372
#
# Evaluating on Test set...
# Accuracy on Test set: 0.9583
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     17532
#            1       1.00      0.56      0.72      1840
#
#     accuracy                           0.96     19372
#    macro avg       0.98      0.78      0.85     19372
# weighted avg       0.96      0.96      0.95     19372

# %% [markdown]
# #### CNN

# %%
cnn_model = deep_trainer.initialize_model("CNN", "fraud_data")
trained_cnn_model = deep_trainer.train_model(cnn_model, "CNN", "fraud_data")
# Out:
# Loading fraud_data dataset...
# Shapes of loaded data for fraud_data:
# X_train: (90402, 12), y_train: (90402,)
# X_val: (19372, 12), y_val: (19372,)
# X_test: (19372, 12), y_test: (19372,)
# Epoch 1/6
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2823/2826 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8266 - loss: 45.0624
# Epoch 1: val_accuracy improved from -inf to 0.90383, saving model to /content/checkpoints/best_CNN_fraud_data.h5
# ...

# %%
deep_trainer.evaluate_model(trained_cnn_model, "fraud_data")
# Out:
# 606/606 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Classification Report for fraud_data:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     17532
#            1       0.91      0.57      0.70      1840
#
#     accuracy                           0.95     19372
#    macro avg       0.93      0.78      0.84     19372
# weighted avg       0.95      0.95      0.95     19372
#
# Accuracy Score for fraud_data: 0.9537476770596738

# %% [markdown]
# #### RNN

# %%
rnn_model = deep_trainer.initialize_model("RNN", "fraud_data")
trained_rnn_model = deep_trainer.train_model(cnn_model, "RNN", "fraud_data")
# Out:
# Loading fraud_data dataset...
# Shapes of loaded data for fraud_data:
# X_train: (90402, 12), y_train: (90402,)
# X_val: (19372, 12), y_val: (19372,)
# X_test: (19372, 12), y_test: (19372,)
# Epoch 1/6
#   17/2826 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9312 - loss: 0.2464
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2809/2826 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9502 - loss: 0.1946
# Epoch 1: val_accuracy improved from -inf to 0.95447, saving model to /content/checkpoints/best_RNN_fraud_data.h5
# ...

# %%
deep_trainer.evaluate_model(trained_rnn_model, "fraud_data")
# Out:
# 606/606 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Classification Report for fraud_data:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     17532
#            1       0.97      0.57      0.71      1840
#
#     accuracy                           0.96     19372
#    macro avg       0.96      0.78      0.85     19372
# weighted avg       0.96      0.96      0.95     19372
#
# Accuracy Score for fraud_data: 0.9568965517241379

# %% [markdown]
# #### LSTM

# %%
lstm_model = deep_trainer.initialize_model("LSTM", "fraud_data")
trained_lstm_model = deep_trainer.train_model(lstm_model, "LSTM", "fraud_data")
# Out:
# Loading fraud_data dataset...
# Shapes of loaded data for fraud_data:
# X_train: (90402, 12), y_train: (90402,)
# X_val: (19372, 12), y_val: (19372,)
# X_test: (19372, 12), y_test: (19372,)
# Epoch 1/6
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2825/2826 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8179 - loss: 18.1869
# Epoch 1: val_accuracy improved from -inf to 0.90429, saving model to /content/checkpoints/best_LSTM_fraud_data.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ...

# %%
deep_trainer.evaluate_model(trained_lstm_model, "fraud_data")
# Out:
# 606/606 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Classification Report for fraud_data:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17532
#            1       0.00      0.00      0.00      1840
#
#     accuracy                           0.91     19372
#    macro avg       0.45      0.50      0.48     19372
# weighted avg       0.82      0.91      0.86     19372
#
# Accuracy Score for fraud_data: 0.9050175511046872
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...
